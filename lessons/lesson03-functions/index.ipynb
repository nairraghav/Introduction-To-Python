# %% [markdown]
# # Functions
# * [Function Basics](function-basics.ipynb)
#     * Docstring
#     * Parameters
#         * args
#         * kwargs
#     * Return
#     * \_\_main__
#     * Recursion

# %% [markdown]
# [Up Next: Lesson 3 - Function Basics](function-basics.ipynb)
#
# [Go Back: Lessons](../index.ipynb)
